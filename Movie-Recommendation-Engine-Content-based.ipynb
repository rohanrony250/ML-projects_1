# %%
import pandas as pd
from math import sqrt
import numpy as np 
import matplotlib.pyplot as plt 
# %matplotlib inline

# %%
movies_df = pd.read_csv('./Movie-Recommendation-Dataset/movies_metadata.csv')
ratings_df = pd.read_csv('./Movie-Recommendation-Dataset/ratings.csv')
movies_df.head()
# Out:
# /home/rohan/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3146: DtypeWarning: Columns (10) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# ...

# %%
#finding columns that have missing values :

missing_data = movies_df.isnull()
missing_data.head()
# Out:
#    adult  belongs_to_collection  budget  genres  homepage     id  imdb_id  \
# 0  False                  False   False   False     False  False    False
# 1  False                   True   False   False      True  False    False
# 2  False                  False   False   False      True  False    False
# 3  False                   True   False   False      True  False    False
# 4  False                  False   False   False      True  False    False
#
#    original_language  original_title  overview  ...  release_date  revenue  \
# 0              False           False     False  ...         False    False
# 1              False           False     False  ...         False    False
# 2              False           False     False  ...         False    False
# 3              False           False     False  ...         False    False
# 4              False           False     False  ...         False    False
#
# ...

# %%
# counting no:of NaN values in each column so as to have a better insight on what to drop


for column in missing_data.columns.values.tolist():
    print(column)
    print(missing_data[column].value_counts(), "\n")
    
#from here we find that columns 'homepage' & 'belongs_to_collection' has most of its values as NaN so it can be avoided for our prediction.
#other columns with missing data can either have its respective empty rows dropped or replaced with frequency/mean/other-functions, whichever method seems fit.
# Out:
# adult
# False    45466
# Name: adult, dtype: int64
#
# belongs_to_collection
# True     40972
# False     4494
# Name: belongs_to_collection, dtype: int64
#
# budget
# False    45466
# Name: budget, dtype: int64
#
# genres
# False    45466
# Name: genres, dtype: int64
#
# homepage
# True     37684
# False     7782
# Name: homepage, dtype: int64
#
# id
# False    45466
# Name: id, dtype: int64
#
# imdb_id
# False    45449
# True        17
# Name: imdb_id, dtype: int64
#
# original_language
# False    45455
# True        11
# Name: original_language, dtype: int64
#
# original_title
# False    45466
# Name: original_title, dtype: int64
#
# overview
# False    44512
# True       954
# Name: overview, dtype: int64
#
# popularity
# False    45461
# True         5
# Name: popularity, dtype: int64
#
# poster_path
# False    45080
# True       386
# Name: poster_path, dtype: int64
#
# production_companies
# False    45463
# True         3
# Name: production_companies, dtype: int64
#
# ...

# %%
#drop homepage and collection column 

movies_df = movies_df.drop(["homepage", "belongs_to_collection", "tagline"], axis=1)

# %%
movies_df.dropna(subset = ["release_date"], axis = 0, inplace = True)
movies_df.reset_index(drop=True, inplace = True)

# %%
movies_df.head()
# Out:
#    adult    budget  genres     id    imdb_id original_language  \
# 0  False  30000000  genres    862  tt0114709                en
# 1  False  65000000  genres   8844  tt0113497                en
# 2  False         0  genres  15602  tt0113228                en
# 3  False  16000000  genres  31357  tt0114885                en
# 4  False         0  genres  11862  tt0113041                en
#
#                 original_title  \
# 0                    Toy Story
# 1                      Jumanji
# 2             Grumpier Old Men
# 3            Waiting to Exhale
# 4  Father of the Bride Part II
#
#                                             overview popularity  \
# 0  Led by Woody, Andy's toys live happily in his ...    21.9469
# 1  When siblings Judy and Peter discover an encha...    17.0155
# 2  A family wedding reignites the ancient feud be...    11.7129
# 3  Cheated on, mistreated and stepped on, the wom...    3.85949
# 4  Just when George Banks has recovered from his ...    8.38752
#
# ...
